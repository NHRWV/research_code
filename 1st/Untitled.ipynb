# %%
import pandas as pd

# %%
all_df = pd.read_excel('all_df (2).xlsx')
before_covid_umap_df = pd.read_excel('before_covid_umap_df(20) (2).xlsx')
covid_umap_df = pd.read_excel('covid_umap_df(20) (2).xlsx')
after_covid_umap_df = pd.read_excel('after_covid_umap_df(20) (2).xlsx')
data = pd.read_excel('영어 키워드 추가 1218.xlsx')

# %%
before = pd.merge(before_covid_umap_df, data, "left", "초록(국문)")
covid = pd.merge(covid_umap_df, data, "left", "초록(국문)")
after = pd.merge(after_covid_umap_df, data, "left", "초록(국문)")
total = pd.merge(all_df, data, "left", "초록(국문)")

# %%
before[before['cluster'] == 2]['성과명']
# Out:
# 25            국내 관광 활성화를 위한 리뷰/소셜 데이터 기반 인공지능 리포트 서비스 개발
# 56                    음성인식 기술을 활용한 여행 안내 콘텐츠 구축 및 서비스 개발
# 85                      자유여행객을 위한 빅데이터 기반 다국어 기계학습 챗봇 개발
# 96     지역 소상공인 매출 확대를 위한 빅테이터와 클라우드 기반 지능형 디지털 광고 플랫폼...
# 102    클라우드 컴퓨팅 기반의 실시간 상황정보 수집 및 제공을 포함하는 사용자 맞춤형 인포...
# 122    방한 중화권 여행객 대상의 실시간 맞춤형 한국관련 콘텐츠 제공 서비스를 위한 자동답...
# 123           공공 문화/예술/관광 콘텐츠 서비스를 위한 대화형 챗봇 프레임워크 기술 개발
# 164                  제주산 로즈마리, 비자잎의 향성분을 함유한 홈케어 스파제품 개발
# 175                   세그먼트 기반의 유사 궤적 검색 및 클러스터링 알고리즘의 개발
# 176                모바일 사용자 및 어플리케이션을 위한 지역 간 클라우드 인프라 연동
# 193          선박용 무선복합측위 지원장치 및 승객 편의서비스 연계 안전구조 지원시스템 개발
# Name: 성과명, dtype: object

# %%
list(before[before['cluster'] == 17]['성과명'])
# Out:
# ['아로니아  사과현미 발효효소 분말 소포장스틱 믹스 제품 개발',
#  '관광지 건축환경의 안전관리 시스템 개발',
#  '지방자치단체 성인지예‧결산제도 분석‧평가사업 : 제도 시행의 성과와 과제',
#  '국내 가구 산업의 해외시장 개척을 위한 글로벌 Framework 디자인 제품 개발사업',
#  '오크통발효공법을 이용한 발포성 로제와인개발',
#  '청정머드를 활용한 인테리어 건축자재, 기능성 침대, 생활용품 개발 지원사업',
#  '퍼지이론을 활용한 농촌관광마을 조성계획의 타당성 평가 및 활용',
#  '정부 부처의 문화·관광 관련 사업의 성인지적 분석과 효율성 제고 방안 : 성인지예산서 대상사업을 중심으로']

# %%
covid[covid['cluster'] == 6]['성과명']
# Out:
# 56       쇠퇴중소도시 활성화를 위한 빅데이터 기반 Multi-Core-City 모델 개발
# 130    4차 산업혁명과 산업의 (재)도시화 및 도시산업공간의 복합·입체적 활용에 관한 연구
# 192            지역혁신형 스마트 산업Hub의 구축모형 및 지방도시 적용 매뉴얼 개발
# 212             쇠퇴하는 지방도시의 지속가능성을 위한 도시 축소 및 재생 전략 개발
# Name: 성과명, dtype: object

# %%
covid[covid['cluster'] == 3]['성과명'] # 후보 1
# Out:
# 160    숲 자원의 복지적, 산업적 활용을 위한 스토리텔링 연구
# 183    산림휴양림 고객경험 서비스 디자인 및 구현에 관한 연구
# 196    경관도로 정비에 의한 경관개선 및 열섬 완화 모델 개발
# Name: 성과명, dtype: object

# %%
covid[covid['cluster'] == 15]['성과명'] # 후보 2
# Out:
# 36      다중 참여형 가상공간 이동 플랫폼 및 시나리오 기반의 콘텐츠 저작 환경 구현 기술 개발
# 46                    지역 체험장 활성화를 위한 VR/AR기반 체험 매칭플랫폼 개발
# 59                      사용자 참여형 문화공간 콘텐츠를 위한 AR 플랫폼 기술개발
# 71     증강현실(AR) 기반 세계유산지역 문화관광 안내서비스를 위한 UIUX 개발연구: 한...
# 153    GPS기반의 3D캐릭터 매핑기술을 이용한 증강현실 모바일 내비게이션을 위한 도시문화...
# 166                  교육관광을 위한 인터렉티브 체험형 AR/VR 콘텐츠 플랫폼 개발
# 205                                   장애인 편의형 VR체험관광 솔루션
# Name: 성과명, dtype: object

# %%
list(covid[covid['cluster'] == 15]['성과명'])
# Out:
# ['다중 참여형 가상공간 이동 플랫폼 및 시나리오 기반의 콘텐츠 저작 환경 구현 기술 개발',
#  '지역 체험장 활성화를 위한 VR/AR기반 체험 매칭플랫폼 개발',
#  '사용자 참여형 문화공간 콘텐츠를 위한 AR 플랫폼 기술개발',
#  '증강현실(AR) 기반 세계유산지역 문화관광 안내서비스를 위한 UIUX 개발연구: 한국의 서원, 세계연속유산을 중심으로',
#  'GPS기반의 3D캐릭터 매핑기술을 이용한 증강현실 모바일 내비게이션을 위한 도시문화콘텐츠 스토리맵 구축',
#  '교육관광을 위한 인터렉티브 체험형 AR/VR 콘텐츠 플랫폼 개발',
#  '장애인 편의형 VR체험관광 솔루션']

# %%
list(covid[covid['cluster'] == 14]['성과명'])
# Out:
# ['2019년도 학교기업 지원사업(서울디지텍고등학교)',
#  '한방소재 융복합 라이프케어 제품 상용화 사업',
#  '축제-행사 공중 콘텐츠 기획을 위한 무선 운영 트러스 모듈 연구개발',
#  '2019년도 학교기업 지원사업 (남서울대학교)']

# %%
temp
# Out:
# ['2019년도 학교기업 지원사업(서울디지텍고등학교)',
#  '한방소재 융복합 라이프케어 제품 상용화 사업',
#  '축제-행사 공중 콘텐츠 기획을 위한 무선 운영 트러스 모듈 연구개발',
#  '2019년도 학교기업 지원사업 (남서울대학교)',
#  '다중 참여형 가상공간 이동 플랫폼 및 시나리오 기반의 콘텐츠 저작 환경 구현 기술 개발',
#  '지역 체험장 활성화를 위한 VR/AR기반 체험 매칭플랫폼 개발',
#  '사용자 참여형 문화공간 콘텐츠를 위한 AR 플랫폼 기술개발',
#  '증강현실(AR) 기반 세계유산지역 문화관광 안내서비스를 위한 UIUX 개발연구: 한국의 서원, 세계연속유산을 중심으로',
#  'GPS기반의 3D캐릭터 매핑기술을 이용한 증강현실 모바일 내비게이션을 위한 도시문화콘텐츠 스토리맵 구축',
#  '교육관광을 위한 인터렉티브 체험형 AR/VR 콘텐츠 플랫폼 개발',
#  '장애인 편의형 VR체험관광 솔루션']

# %%
list(after[after['cluster'] == 17]['성과명'])
# Out:
# ['스마트 도로조명 플랫폼 개발 및 실증 연구',
#  'GNSS와 점 구름을 이용한 증강 콘텐츠의 좌표 보정을 통한 일관성 있는 협업 시스템',
#  '딥러닝 기반 유리 왜곡 모델링 및 영상 복원 기술 개발',
#  '차세대 디스플레이 및 스마트 윈도우 응용을 위한 고성능 액정소자 핵심기술 개발',
#  '항공 LiDAR와 다중 공간정보 데이터를 이용한 딥러닝 모델',
#  '스마트카 다중 센서와 딥러닝을 이용한 초정밀 내츄럴 3D 뷰 생성 기술 개발',
#  '무인항공기 영상을 활용한 차세대 산림위성영상의 기하 품질 개선',
#  '5G 기반 다자 실감형 관광 체험 가이드 기술 개발',
#  '야간 문화관광을 위한 플렉서블 LED 조각보 기반 감성문화 콘텐츠 개발']

# %%
list(after[after['cluster'] == 11]['초록(국문)'])
# Out:
# ["... 농산물 판매를 하지 못해 피해 발생○ MZ 세대를 중심으로 '러스틱라이프' 유행 ➞ 시골 여행객 증가□ 내적동기○ 부모님(인삼농사)께서 재배 시기에 일손을 찾는데 어려움을 느낌○ 현재 대학생이다 ... 해결 및 여행객 니즈 충족○ 농촌 문제 해결- 인력 매칭을 통한 농가의 일손부족 해결- 농촌 관광을 하는 사람이 늘어나며 농촌 지방소멸 문제 해결- 농촌 관광 홍보 해결○ 여행객 니즈 충족- ..."]

# %%
list(total[total['cluster'] == 24]['성과명'])
# Out:
# ['환경평가 지원을 위한 지역 환경현황 분석 시스템 구축 및 운영: 개발사업 현황분석 및 EA-INDEX 고도화 (관광단지, 폐기물 처리시설 개발사업)',
#  '글로벌 인문교양교육 모델 개발 기초 연구',
#  '모듈화 기술융합형 휴대용 정수제품 및 ICT 서비스 기술 개발',
#  '컨퍼런스 최신 연구 동향 분석 : 언어네트워크 분석과 빅데이터 분석을 적용한 Generic Platform 개발',
#  '지능형 차량 및 교통시스템의 고안전성 보장을 위한 사이버물리시스템 기반 융합 플랫폼 기술 개발',
#  '핵융합 전문인력양성 프로그램',
#  '역사지도 데이타베이스 구축을 통한 한국 비무장지대(DMZ)와 독일 그뤼네스반트의 토지이용 및 토지피복 변화 분석',
#  'V2X 기반 철도 이동 통신 및 스마트 교통 ICT 융합 서비스를 위한 국제 표준화',
#  '천리안/Metop-A 위성자료를 이용한 황사 발생 예측 정확도 개선 연구',
#  '생물다양성협약 이행·지원 프로그램 기획·운영',
#  '수송부문 국가대기오염물질 통계 구축',
#  '개도국 교육지표 개발·협력 사업 : 아시아 중점협력국가를 중심으로',
#  '메디컬 검사실 표준(ISO 15189) 확산을 통한 의료산업 선진화 및 국제상호인정을 위한 기반조성',
#  'OECD/NEA 참여 확대 및 효과적 활동 관리 방안 마련 연구',
#  '지속가능한 동시베리아 지역공동체 발전전략 연구',
#  '전환기 남북관계 발전 추진 방안',
#  '영남씨그랜트사업',
#  '제약기업 수출 경쟁력 확보를 위한 아세안 국가 의약품 관련 특허제도 연구',
#  'Beta-carotene의 receptor와 대사효소 조절을 통한 암줄기세포 특성과 전이에 미치는 항암효과 및 기전 탐색',
#  '북중관계 주요분야별 현황 분석',
#  '송도 SW융합 클러스터 (인천 SW융합 BI-Plex)',
#  '창업지원 효율화 및 창업기업 진입장벽 해소 방안 연구',
# ...

# %%
list(total[total['cluster'] == 24]['초록(국문)'])
# Out:
# ['Ⅲ. 연구 결과❏ 연구대상 기간 내 국내 관광단지 개발사업은 총 52건의 환경영향평가 협의를 득하였으며, 매년 3~6건 정도의 범위에서 협의가 이루어진 것으로 나타났음. 총 52건의 사업을 통한 관광단지 개발 총면적은 약 49.9km2이며, 개발사업 1건당 평균 약 0.96km2의 규모로 개발이 이루어졌음. 지역별 개발현황 분석 결과 경기도에서 12건으로 가장 ...',
#  '본 연구는 글로벌 보편성을 갖춤으로써 세계의 다양한 국가에서 공통으로 활용할 수 있는 인문교양교육의 모델을 개발하기 위한 기초연구이다. 세계는 공통의 위기와 문제를 겪고 있으며, 우리는 인간으로서 이를 함께 극복하고 보다 좋은 세상을 창조해야 할 의무와 책임이 있다. 본 연구는 우리나라가 주도하여 인문교양교육의 중요성과 역할을 재조명하고, 이것이 현실에서 ...',
#  "... 있는 가능성을 가지고 있으며, 국내뿐 아닌, 해외 수질 현황을 포함하는 글로벌 수질 정보 플랫폼으로 확장하여'Purisoo+' 및 'PuriSense','PuriMer'등의 수출활로를 열 것으로 기대□ 적용 분야○ 소비재 및 생활산업 분야 (여행용품, 스포츠용품)○ 여가 및 헬스케어 서비스 분야 (ICT 서비스)(출처 : 기술개발사업 최종보고서 초록 5p)",
#  '□ 과제목표본 과제의 최종 목표는 컨퍼런스 최신 연구 동향을 분석하기 위하여 언어네트워크 분석과 빅데이터 분석을 적용한 Generic Platform을 개발하는 것이다. 과제 수행기간은 총 1년(19.07.01~20.06.30)으로, 전반부에 해당하는 1차년도에는 AAG(Association for American Geographer) 컨퍼런스에 20년간 ...',
# ...

# %%
covid['cluster'].value_counts()
# Out:
# 8     26
# 10    24
# 19    22
# 13    19
# 1     17
# 5     16
# 7     16
# 11    16
# 12    10
# 9     10
# 2      9
# 15     7
# 4      6
# 17     5
# 18     4
# 6      4
# 14     4
# 0      3
# 3      3
# 16     2
# Name: cluster, dtype: int64
